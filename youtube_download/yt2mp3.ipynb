# %%
# 操作 browser 的 API
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# ChromeDriver 的下載管理工具
from webdriver_manager.chrome import ChromeDriverManager

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# 子處理程序，用來取代 os.system 的功能
import subprocess

# 下載檔案的工具
import wget



'''
Selenium with Python 中文翻譯文檔
參考網頁：https://selenium-python-zh.readthedocs.io/en/latest/index.html
selenium 啓動 Chrome 的進階配置參數
參考網址：https://stackoverflow.max-everyday.com/2019/12/selenium-chrome-options/
'''

# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options
)

# 建立儲存圖片、影片的資料夾
folderPath = 'youtubemp3'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 放置爬取的資料
listData = []

# %%
def visit():
    driver.get("https://www.youtube.com/")

# 輸入關鍵字
def search():
    txt_input = driver.find_element(By.CSS_SELECTOR, "input#search")
    txt_input.send_keys("夜に駆ける")

    txt_input.submit()


def scroll():
    innerHeight = 0
    offset = 0
    count = 0
    limit = 3

    while count <= limit :
        offset = driver.execute_script("return document.documentElement.scrollHeight")

        driver.execute_script(f"""
            window.scrollTo({{
                top: {offset}, 
                behavior: "smooth"
            }});
        """)

        sleep(3)

        innerHeight = driver.execute_script(
            "return document.documentElement.scrollHeight;"
        )


        if offset == innerHeight:
            count += 1

        if offset >= 600:
            break
        
        

def parse():
    global listData

    listData.clear()


    elements = driver.find_elements(
        By.CSS_SELECTOR,
        "ytd-video-renderer.style-scope.ytd-item-section-renderer"
    )

    for elm in elements:
        print("=" * 30)

        img = elm.find_element(
            By.CSS_SELECTOR,
            "a#thumbnail img"
        )
        imgSrc = img.get_attribute("src")
        print(imgSrc)

        a = elm.find_element(
            By.CSS_SELECTOR,
            "a#video-title"
        )
        aTitle = a.get_attribute("innerText")
        print(aTitle)
        
        aLink = a.get_attribute("href")
        print(aLink)
        
        strDelimiter = ""
        if "shorts" in aLink:
            strDelimiter = "/shorts/"
        else:
            strDelimiter = "v="
            
        youtube_id = aLink.split(strDelimiter)[1]
        youtube_id = youtube_id.split("&pp")[0]
        print(youtube_id)

        listData.append({
            "id": youtube_id,
            "title": aTitle,
            "link": aLink,
            "img": imgSrc
        })


def saveJson():
    with open(f"{folderPath}/youtube.json", "w", encoding = "utf-8") as file:
        file.write(json.dumps(listData, ensure_ascii=False, indent=4))

def close():
    driver.quit()

# %%
visit()
search()
scroll()
parse()
saveJson()
close()
# Out:
# ==============================
# https://i.ytimg.com/vi/x8VYWazR5mE/hq720.jpg?sqp=-oaymwEiCNAFEJQDSFXyq4qpAxQIARUAAIhCGAFwAcABBu0BZmZmQg==&rs=AOn4CLCQtmFasS17HRy3a1Oq-Mz2ZlEL9Q
# YOASOBI「夜に駆ける」 Official Music Video
# https://www.youtube.com/watch?v=x8VYWazR5mE&pp=ygUP5aSc44Gr6aeG44GR44KL
# x8VYWazR5mE
# ==============================
# https://i.ytimg.com/vi/j1hft9Wjq9U/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDApXy6l4o_TU8J9_eTRUyeVSiRIQ
# YOASOBI - 夜に駆ける / THE HOME TAKE
# https://www.youtube.com/watch?v=j1hft9Wjq9U&pp=ygUP5aSc44Gr6aeG44GR44KL
# j1hft9Wjq9U
# ==============================
# https://i.ytimg.com/vi/mTdfEMAa72s/hqdefault.jpg?sqp=-oaymwE2COADEI4CSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARgTIBwofzAP&rs=AOn4CLA1jf44s69Lbb4gzG6Yls-1NgQcFQ
# 夜に駆ける - YOASOBI -Lyrics Video【中文日文羅馬拼音歌詞字幕】
# https://www.youtube.com/watch?v=mTdfEMAa72s&pp=ygUP5aSc44Gr6aeG44GR44KL
# mTdfEMAa72s
# ==============================
# https://i.ytimg.com/vi/GEIf9Dp6GgQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCQUzHE5KwATFluZRCDLoOMr7Txjg
# YOASOBI 夜に駆ける
# https://www.youtube.com/watch?v=GEIf9Dp6GgQ&pp=ygUP5aSc44Gr6aeG44GR44KL
# GEIf9Dp6GgQ
# ==============================
# https://i.ytimg.com/vi/jpq1jKNNPTo/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCkQ2evVBDzTFsVEDJkVMWO0PhLIA
# YOASOBI - 夜に駆ける (밤을 달리다) [한국어 자막 / 가사 번역]
# https://www.youtube.com/watch?v=jpq1jKNNPTo&pp=ygUP5aSc44Gr6aeG44GR44KL
# jpq1jKNNPTo
# ==============================
# https://i.ytimg.com/vi/xViQc7M2eB8/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDYs-UlhI4CLgjVea_g8EeMO4SL1A
# 夜に駆ける×1時間永久
# https://www.youtube.com/watch?v=xViQc7M2eB8&pp=ygUP5aSc44Gr6aeG44GR44KL
# xViQc7M2eB8
# ==============================
# https://i.ytimg.com/vi/J7Ft5vGaQKI/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAly25ejfUL--gwOlJZLtV9wfp7pg
# 【歌詞付き･超高音質】夜に駆ける
# https://www.youtube.com/watch?v=J7Ft5vGaQKI&pp=ygUP5aSc44Gr6aeG44GR44KL
# J7Ft5vGaQKI
# ==============================
# https://i.ytimg.com/vi/h5NT9g_lxEI/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDWWauHtIbmTk5-nJk-fyEECOUObA
# 【YOASOBI】夜に駆ける 歌詞付き
# https://www.youtube.com/watch?v=h5NT9g_lxEI&pp=ygUP5aSc44Gr6aeG44GR44KL
# h5NT9g_lxEI
# ==============================
# https://i.ytimg.com/vi/5tbrCym8Dso/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCGboriz4ci9T2svQPJ_tjYPv6ENA
# 【YOASOBI】夜に駆ける 瓦西瓦瓦 / Vaswawa Cover 歌ってみた
# https://www.youtube.com/watch?v=5tbrCym8Dso&pp=ygUP5aSc44Gr6aeG44GR44KL
# 5tbrCym8Dso
# ==============================
# https://i.ytimg.com/vi/O_aOUc_ppQA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLABNUv28FDuYZEkuaiClNvNovl4FA
# 【MAD】ハイキュー‼︎及川徹×YOASOBI「夜に駆ける」
# https://www.youtube.com/watch?v=O_aOUc_ppQA&pp=ygUP5aSc44Gr6aeG44GR44KL
# O_aOUc_ppQA
# ==============================
# https://i.ytimg.com/vi/2Ey3FEAth0s/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA-lb9FuBv6wa3K4qd4fg78Lqj9TA
# 鬼滅の刃MAD『夜に駆ける』
# https://www.youtube.com/watch?v=2Ey3FEAth0s&pp=ygUP5aSc44Gr6aeG44GR44KL
# 2Ey3FEAth0s
# ==============================
# https://i.ytimg.com/vi/_ZtBv0hTm1w/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC60klXaT-h3zSzXOGkA5l0FJrwpA
# YOASOBI「夜に駆ける」 from 『ROCK IN JAPAN FESTIVAL 2022』2022.8.06@千葉市蘇我スポーツ公園
# https://www.youtube.com/watch?v=_ZtBv0hTm1w&pp=ygUP5aSc44Gr6aeG44GR44KL
# _ZtBv0hTm1w
# ==============================
# https://i.ytimg.com/vi/ul5WOXNgZd8/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA30nbE61uqaiUpe4uz43dFPE4Nrg
# 【MAD】夜に駆ける-Fortnite-
# https://www.youtube.com/watch?v=ul5WOXNgZd8&pp=ygUP5aSc44Gr6aeG44GR44KL
# ul5WOXNgZd8
# ==============================
# https://i.ytimg.com/vi/rpb-OD2mtvU/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD4hUno4UqlSuIyDLxI3CEDEhHR5g
# 【MAD/AMV】推しの子×夜に駆ける
# https://www.youtube.com/watch?v=rpb-OD2mtvU&pp=ygUP5aSc44Gr6aeG44GR44KL
# rpb-OD2mtvU
# ==============================
# https://i.ytimg.com/vi/yOFcd2227lw/hq720.jpg?sqp=-oaymwE2CNAFEJQDSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB1AaAAuADigIMCAAQARh_IC8oUzAP&rs=AOn4CLBF96FTOlrCyAdGlFaRhyoAOoeo7A
# YOASOBI『夜に駆ける』The First Take (速度修復) / 中日羅馬拼音歌詞
# https://www.youtube.com/watch?v=yOFcd2227lw&pp=ygUP5aSc44Gr6aeG44GR44KL
# yOFcd2227lw
# ==============================
# https://i.ytimg.com/vi/L5JF132P30s/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBFbRLBwJZ2wOX5UqMJann0V__gIw
# YOASOBI / 夜に駆ける (Covered by コバソロ & こぴ)
# https://www.youtube.com/watch?v=L5JF132P30s&pp=ygUP5aSc44Gr6aeG44GR44KL
# L5JF132P30s
# ==============================
# https://i.ytimg.com/vi/MdC3nKfsif4/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLChMumE9ycuv4_ukIxIxfgnrOdHFw
# 【MAD】Fate/Grand Order 『夜に駆ける』
# https://www.youtube.com/watch?v=MdC3nKfsif4&pp=ygUP5aSc44Gr6aeG44GR44KL
# MdC3nKfsif4
# ==============================
# https://i.ytimg.com/vi/JPzDqIJ0TDE/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCQ2ntcUgNWgKhyk6HxgnpZX2uIzg
# [MAD]　夜に駆ける (YOASOBI) ×鬼滅の刃 〜胡蝶姉妹Ver.〜 (※ネタバレ注意)
# https://www.youtube.com/watch?v=JPzDqIJ0TDE&pp=ygUP5aSc44Gr6aeG44GR44KL
# JPzDqIJ0TDE
# ==============================
# https://i.ytimg.com/vi/K7OUQxmhcQg/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDwt7eb4BmFBKms3_m0KBijMkYjJw
# 【生徒と講師で歌う】夜に駆ける / YOASOBI【歌い方解説付き by シアーミュージック】
# https://www.youtube.com/watch?v=K7OUQxmhcQg&pp=ygUP5aSc44Gr6aeG44GR44KL
# K7OUQxmhcQg
# ==============================
# https://i.ytimg.com/vi/qTlulMa2Q24/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDxdZmuQUkvIflDHJemW8ybb0kzFQ
# 【原神MV】夜に駆ける YOASOBI × Genshin Impact 【MAD】【AMV/GMV】
# https://www.youtube.com/watch?v=qTlulMa2Q24&pp=ygUP5aSc44Gr6aeG44GR44KL
# qTlulMa2Q24
# ==============================
# None
# YOASOBI 夜に駆ける (10 HOURS)
# https://www.youtube.com/watch?v=pyYDtY_xpSE&pp=ygUP5aSc44Gr6aeG44GR44KL
# pyYDtY_xpSE
# ==============================
# None
# 陸上自衛隊中央音楽隊 ♪YOASOBIメドレー（怪物～祝福～アイドル～群青～夜に駆ける）/ 木曜コンサート 2024.6.20 新宿三井ビル
# https://www.youtube.com/watch?v=JbuSzBczlj4&pp=ygUP5aSc44Gr6aeG44GR44KL
# JbuSzBczlj4
# ==============================
# None
# 兰音Reine • Tacitly｜夜に駆ける
# https://www.youtube.com/watch?v=WX_ep7xCWi4&pp=ygUP5aSc44Gr6aeG44GR44KL
# WX_ep7xCWi4
# ==============================
# None
# 夜に駆ける　2024年西久保八幡神社盆踊り32　東京都港区
# https://www.youtube.com/watch?v=6sLC_SC4ng8&pp=ygUP5aSc44Gr6aeG44GR44KL
# 6sLC_SC4ng8
# ==============================
# None
# We;Na(위나) - ” YOASOBI - 夜に駆ける ” cover 　 2024.08.18 2部撮影可能曲
# https://www.youtube.com/watch?v=BJdNZbeT2nw&pp=ygUP5aSc44Gr6aeG44GR44KL
# BJdNZbeT2nw
# ==============================
# None
# アヤベさんに夜に駆けるを歌ってもらった
# https://www.youtube.com/watch?v=s2uy_6OCAH8&pp=ygUP5aSc44Gr6aeG44GR44KL
# s2uy_6OCAH8
# ==============================
# None
# Ayase and Ikura's random conversation - YOASOBI - Yoru ni Kakeru 夜に駆ける (Racing Into The Night) in NY
# https://www.youtube.com/watch?v=f1pRSncn7OM&pp=ygUP5aSc44Gr6aeG44GR44KL
# f1pRSncn7OM
# ==============================
# None
# YOASOBI - 夜に駆ける (밤을 달리다) 『240615 2024 Weverse Con Festival』
# https://www.youtube.com/watch?v=TIo0a0LlZNs&pp=ygUP5aSc44Gr6aeG44GR44KL
# TIo0a0LlZNs
# ==============================
# None
# 【盆踊り】 夜に駆ける（YOASOBI）　安城市高棚 町内盆踊り大会2024
# https://www.youtube.com/watch?v=j3to9m4Vo5g&pp=ygUP5aSc44Gr6aeG44GR44KL
# j3to9m4Vo5g
# ==============================
# None
# 【MAD】五等分の花嫁 2nd Season×夜に駆ける 修正版
# https://www.youtube.com/watch?v=O7tstkqkbXQ&pp=ygUP5aSc44Gr6aeG44GR44KL
# O7tstkqkbXQ
# ==============================
# None
# 【VOICEVOXハミング】夜に駆ける feat.WhiteCUL
# https://www.youtube.com/watch?v=NWryCJHuQL8&pp=ygUP5aSc44Gr6aeG44GR44KL
# NWryCJHuQL8
# ==============================
# None
# 【MMD】夜に駆けるYOASOBI（手話）【MMDモーション配布】【MMDカメラ配布】
# https://www.youtube.com/watch?v=dH2mfHfC3qs&pp=ygUP5aSc44Gr6aeG44GR44KL
# dH2mfHfC3qs
# ==============================
# None
# 夜に駆ける　太鼓の達人　クリア成功‼️
# https://www.youtube.com/watch?v=1sY2dYktddE&pp=ygUP5aSc44Gr6aeG44GR44KL
# 1sY2dYktddE
# ==============================
# None
# 요아소비 밤을 달리다 (YOASOBI - 「夜に駆ける」) Bass Cover
# https://www.youtube.com/watch?v=Qx1WsLfLVJw&pp=ygUP5aSc44Gr6aeG44GR44KL
# Qx1WsLfLVJw
# ==============================
# None
# 夜に駆ける（cover）
# https://www.youtube.com/watch?v=5Krud45wgLg&pp=ygUP5aSc44Gr6aeG44GR44KL
# 5Krud45wgLg
# ==============================
# None
# 【キーボ弾いてみた】夜に駆ける/YOASOBI/Yoru ni Kakeru ［バンド演奏用］
# https://www.youtube.com/watch?v=umozaaokfqg&pp=ygUP5aSc44Gr6aeG44GR44KL
# umozaaokfqg
# ==============================
# None
# YOASOBI-夜に駆ける(口琴版 By DoNo)
# https://www.youtube.com/watch?v=K8ZMmziIJHA&pp=ygUP5aSc44Gr6aeG44GR44KL
# K8ZMmziIJHA
# ==============================
# None
# 【文字pv】夜に駆ける
# https://www.youtube.com/watch?v=58wdMCI4eqQ&pp=ygUP5aSc44Gr6aeG44GR44KL
# 58wdMCI4eqQ
# ==============================
# None
# キタサンブラックに夜に駆けるを歌ってもらった
# https://www.youtube.com/watch?v=5R4eyXmC5yU&pp=ygUP5aSc44Gr6aeG44GR44KL
# 5R4eyXmC5yU

# %%
def download():
    if not os.path.exists("./yt-dlp.exe"):
        print("[下載 yt-dlp]")
        wget.download("https://github.com/yt-dlp/yt-dlp/releases/latest/download/yt-dlp.exe", "./yt-dlp.exe")


    with open(f"{folderPath}/youtube.json", "r", encoding= "utf-8") as file:
        strJson = file.read()


    listResult = json.loads(strJson)

    for index, obj in enumerate(listResult):
        if index == 3:
            break

        print(f"正在下載: {obj['link']}")


        cmd = [
            "./yt-dlp.exe",
            obj["link"],
            "-f",
            "ba",
            "-o",
            f"{folderPath}/%(title)s.%(ext)s"
        ]

        obj_sp = subprocess.run(cmd)

        if obj_sp.returncode == 0:
            print("success!")
        else:
            print("fail!")

# %%
download()
# Out:
# 正在下載: https://www.youtube.com/watch?v=x8VYWazR5mE&pp=ygUP5aSc44Gr6aeG44GR44KL
# success!
# 正在下載: https://www.youtube.com/watch?v=j1hft9Wjq9U&pp=ygUP5aSc44Gr6aeG44GR44KL
# success!
# 正在下載: https://www.youtube.com/watch?v=mTdfEMAa72s&pp=ygUP5aSc44Gr6aeG44GR44KL
# success!
